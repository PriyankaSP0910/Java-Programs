# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('C:/Users/DS3/Downloads/mpg_raw.csv')

# %%
df.info()
df.shape
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# ...

# %% [markdown]
# df.isna().sum()
# df.dropna()

# %%
df.isna().sum()
df.dropna()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
plt.hist(df['acceleration'])
# Out:
# (array([ 6., 15., 50., 86., 92., 80., 45., 13.,  7.,  4.]),
#  array([ 8.  ,  9.68, 11.36, 13.04, 14.72, 16.4 , 18.08, 19.76, 21.44,
#         23.12, 24.8 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.violinplot(x=df['mpg'],y=df['origin'])
# Out:
# <Axes: xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(df['acceleration'])
# Out:
# <Axes: >

# %%
q1=df['acceleration'].quantile(0.25)
q3=df['acceleration'].quantile(0.75)
iqr=q3-q1
print(q1)
print(q3)
print(iqr)
lw=q1-1.5*iqr
uw=q3+1.5*iqr
print(lw,uw)
# Out:
# 13.825000000000001
# 17.175
# 3.3499999999999996
# 8.8 22.2

# %%
sns.boxplot(df['acceleration'])
# Out:
# <Axes: >

# %%
df['acceleration']=np.where(df['acceleration']>20,20,df['acceleration'])

# %%
df['acceleration']=np.where(df['acceleration']<10,10,df['acceleration'])

# %%
sns.boxplot(df['acceleration'])
# Out:
# <Axes: >

# %%
df[['acceleration']].boxplot()
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(method='spearman'),annot=True,vmin=1,vmax=1)
# Out:
# C:\Users\DS3\AppData\Local\Temp\ipykernel_6764\520121328.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(method='spearman'),annot=True,vmin=1,vmax=1)
# <Axes: >

# %%
sns.heatmap(df.corr(method='spearman'),annot=True,vmin=0,vmax=1)
# Out:
# C:\Users\DS3\AppData\Local\Temp\ipykernel_6764\858351446.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(method='spearman'),annot=True,vmin=0,vmax=1)
# <Axes: >

# %%
num=list[df.select_dtypes(exclude=['object']).columns]

# %%
num
# Out:
# list[Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year'],
#       dtype='object')]

# %%
from sklearn.preprocessing import MinMaxScaler()
columns_to_scale=['mpg','cylinders','displacement','horsepower','weight''acceleration','model_year']
scaler=StandardScaler()
data[columns_to_scale]=scaler.fit_transform(data[columns_to_scale])
# Out:
#   Cell In[48], line 1
#     from sklearn.preprocessing import MinMaxScaler()
#                                                   ^
# SyntaxError: invalid syntax

# %%
plt.hist(df['horsepower'])
# Out:
# (array([ 27.,  95., 120.,  44.,  19.,  47.,  13.,  14.,   5.,   8.]),
#  array([ 46. ,  64.4,  82.8, 101.2, 119.6, 138. , 156.4, 174.8, 193.2,
#         211.6, 230. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.scatterplot(x=df['displacement'],y=df['horsepower'])
# Out:
# <Axes: xlabel='displacement', ylabel='horsepower'>

# %%
sns.countplot(x='origin',data=df)
# Out:
# <Axes: xlabel='origin', ylabel='count'>

# %%
sns.pointplot(x='acceleration',y='origin',data=df)
# Out:
# <Axes: xlabel='acceleration', ylabel='origin'>

# %%
sns.pairplot(df)

# %%
sns.barplot(x='acceleration',y='horsepower',data=df)
plt.show()
# Out:
# C:\ProgramData\anaconda31\lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))

# %%
sns.barplot(x='cylinders',y='weight',data=df)
plt.show()

# %%
sns.scatterplot(x="displacement",y="horsepower",hue="cylinders",data=df)
# Out:
# <Axes: xlabel='displacement', ylabel='horsepower'>

# %%
from sklearn.preprocessing import StandardScaler
cont=['mpg','cylinders','displacement','horsepower']
scaler=StandardScaler()
df[cont]=scaler.fit_transform(df[cont])
df[cont]
# Out:
#           mpg  cylinders  displacement  horsepower
# 0   -0.706439   1.498191      1.090604    0.664133
# 1   -1.090751   1.498191      1.503514    1.574594
# 2   -0.706439   1.498191      1.196232    1.184397
# 3   -0.962647   1.498191      1.061796    1.184397
# 4   -0.834543   1.498191      1.042591    0.924265
# ..        ...        ...           ...         ...
# 393  0.446497  -0.856321     -0.513026   -0.480448
# 394  2.624265  -0.856321     -0.925936   -1.364896
# 395  1.087017  -0.856321     -0.561039   -0.532474
# 396  0.574601  -0.856321     -0.705077   -0.662540
# 397  0.958913  -0.856321     -0.714680   -0.584501
#
# [398 rows x 4 columns]
